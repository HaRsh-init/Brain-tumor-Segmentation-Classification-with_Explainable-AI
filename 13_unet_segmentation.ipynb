# %% [markdown]
# # UNet Segmentation with Improvements
# This notebook demonstrates the improved code for segmentation using the segmentation_models library.
# ## Key Improvements:
# - Use of segmentation_models library with scSE attention.
# - Initial setting of encoder_freeze=False.
# - Optimized loss functions from segmentation_models.
# - Early debugging cell for model predictions.
# - Implementation of F1 score metric.
# - Improved learning rate of 1e-4 with better early stopping criteria.
# - Comprehensive comments for understanding.

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from segmentation_models import Unet
from segmentation_models.utils import set_data_format
from keras.callbacks import EarlyStopping
from sklearn.metrics import f1_score
# Additional imports as needed
set_data_format('channels_last')

# %%
# Load your data here
# data = ...

# %%
# Initialize model
model = Unet('resnet34', encoder_freeze=False, activation='sigmoid')
# Compile model with optimized loss
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[f1_score])

# %%
# Early debugging cell
def debug_predictions(model, data):
    # Function to visualize model predictions
    pass  # Code for debugging predictions

# %%
# Fit the model
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1)
history = model.fit(X_train, y_train, validation_data=(X_val, y_val),
                    epochs=50,
                    callbacks=[early_stopping])

# %% [markdown]
# ## Results
# - Add your evaluation results here
